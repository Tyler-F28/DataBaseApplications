# %%
import pandas as pd
import sqlite3

# Connect to database
conn = sqlite3.connect('nba_5seasons.db')
print("✅ Connected to nba_5seasons.db")
# Out:
# ✅ Connected to nba_5seasons.db

# %%
# SQL query to list all tables in the SQLite database
query = """
SELECT name
FROM sqlite_master
WHERE type='table'
ORDER BY name;
"""

# Run the query and load the results into a pandas DataFrame
tables = pd.read_sql(query, conn)

# Display the table names
tables
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []

# %%
pd.read_sql("PRAGMA table_info(player_season_stats);", conn)
# Out:
# Empty DataFrame
# Columns: [cid, name, type, notnull, dflt_value, pk]
# Index: []

# %%
pd.read_sql("PRAGMA table_info(players);", conn)
# Out:
# Empty DataFrame
# Columns: [cid, name, type, notnull, dflt_value, pk]
# Index: []

# %%
pd.read_sql("PRAGMA table_info(team_game_stats);", conn)
# Out:
# Empty DataFrame
# Columns: [cid, name, type, notnull, dflt_value, pk]
# Index: []

# %%
pd.read_sql("PRAGMA table_info(teams);", conn)
# Out:
# Empty DataFrame
# Columns: [cid, name, type, notnull, dflt_value, pk]
# Index: []

# %%
# How many teams are in our database?
query = "select" Count(*)
SELECT COUNT(*) as total_teams
FROM teams
"total_teams"from"

result = pd.read_sql(query, conn)
print("Total NBA Teams:")
display(result)

# COUNT(*) counts all rows in the table
# Out:
#   Cell In[17], line 5
#     "total_teams"from"
#                      ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
# How many player-season records for 2021-22?

SELECT COUNT(*) as player_records
FROM player_season_stats
WHERE season = '2021-22'


result = pd.read_sql(query, conn)
print("Player Season Records (2021-22):")
display(result)

# This counts how many players have stats recorded for that season
# Out:
#   Cell In[21], line 3
#     SELECT COUNT(*) as player_records
#                   ^
# SyntaxError: Invalid star expression

# %%
# Highest and lowest scores in any game (2021-22)
query = """
SELECT 
    MIN(pts) as lowest_score,
    MAX(pts) as highest_score,
    MAX(pts) - MIN(pts) as score_range
FROM team_game_stats
WHERE season = '2021-22'
"""

result = pd.read_sql(query, conn)
print("Scoring Range for 2021-22 Season:")
display(result)

# Shows the extremes and calculates the range
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: team_game_stats
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[22], line 11
#       1 # Highest and lowest scores in any game (2021-22)
#       2 query = """
#       3 SELECT
#       4     MIN(pts) as lowest_score,
#    (...)      8 WHERE season = '2021-22'
#       9 """
# ---> 11 result = pd.read_sql(query, conn)
#      12 print("Scoring Range for 2021-22 Season:")
#      13 display(result)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     MIN(pts) as lowest_score,
#     MAX(pts) as highest_score,
#     MAX(pts) - MIN(pts) as score_range
# FROM team_game_stats
# WHERE season = '2021-22'
# ': no such table: team_game_stats

# %%
# Comprehensive stats for all 2021-22 games
query = """
SELECT 
    COUNT(*) as total_games,
    SUM(pts) as total_points,
    ROUND(AVG(pts), 1) as avg_points,
    MIN(pts) as min_score,
    MAX(pts) as max_score
FROM team_game_stats
WHERE season = '2021-22'
"""

result = pd.read_sql(query, conn)
print("2021-22 Season Statistics Summary:")
display(result)

# One query gives us a complete statistical overview
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: team_game_stats
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[23], line 13
#       1 # Comprehensive stats for all 2021-22 games
#       2 query = """
#       3 SELECT
#       4     COUNT(*) as total_games,
#    (...)     10 WHERE season = '2021-22'
#      11 """
# ---> 13 result = pd.read_sql(query, conn)
#      14 print("2021-22 Season Statistics Summary:")
#      15 display(result)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     COUNT(*) as total_games,
#     SUM(pts) as total_points,
#     ROUND(AVG(pts), 1) as avg_points,
#     MIN(pts) as min_score,
#     MAX(pts) as max_score
# FROM team_game_stats
# WHERE season = '2021-22'
# ': no such table: team_game_stats

# %%
# Without GROUP BY - just counts ALL games
query = """
SELECT COUNT(*) as total_games
FROM team_game_stats
WHERE season = '2021-22'
"""

result = pd.read_sql(query, conn)
print("Total games across all teams:")
display(result)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: team_game_stats
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[24], line 8
#       1 # Without GROUP BY - just counts ALL games
#       2 query = """
#       3 SELECT COUNT(*) as total_games
#       4 FROM team_game_stats
#       5 WHERE season = '2021-22'
#       6 """
# ----> 8 result = pd.read_sql(query, conn)
#       9 print("Total games across all teams:")
#      10 display(result)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT COUNT(*) as total_games
# FROM team_game_stats
# WHERE season = '2021-22'
# ': no such table: team_game_stats
