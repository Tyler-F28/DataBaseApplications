# %%
import pandas as pd
import sqlite3

# Connect to database
conn = sqlite3.connect('nba_2022-2023.xlsx')
print("✅ Connected to database")
# Out:
# ✅ Connected to database

# %%
# TODO: Write your query
query_1 = "Select From teams count(*)"



result_1 = pd.read_sql(query_1, conn)
display(result_1)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: near "From": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[14], line 6
#       1 # TODO: Write your query
#       2 query_1 = "Select From teams count(*)"
# ----> 6 result_1 = pd.read_sql(query_1, conn)
#       7 display(result_1)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'Select From teams count(*)': near "From": syntax error

# %%
# TODO: Write your query
query_2 = "FROM player_season_stats"

"WHERE season =2021-22"
# Out:
# 'WHERE season =2021-22'

# %%
# TODO: Write your query
query_3 = "sum(pts) from team_game_stats"WHERE season=2021-22"



result_3 = pd.read_sql(query_3, conn)
display(result_3)
# Out:
#   Cell In[16], line 2
#     query_3 = "sum(pts) from team_game_stats"WHERE season=2021-22"
#                                                                  ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# TODO: Write your query
query_4 = "AVG(pts)"FROM team_game_stats"

"""

result_4 = pd.read_sql(query_4, conn)
display(result_4)
# Out:
#   Cell In[17], line 2
#     query_4 = "AVG(pts)"FROM team_game_stats"
#                                             ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# TODO: Write your query
query_5 = "MAX(pts)"MIN(pts)"

"""

result_5 = pd.read_sql(query_5, conn)
display(result_5)
# Out:
#   Cell In[18], line 2
#     query_5 = "MAX(pts)"MIN(pts)"
#                                 ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# TODO: Write your query
query_6 = "SUM(pts)""WHERE=1610612747"



result_6 = pd.read_sql(query_6, conn)
display(result_6)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: near "SUM": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[21], line 6
#       1 # TODO: Write your query
#       2 query_6 = "SUM(pts)""WHERE=1610612747"
# ----> 6 result_6 = pd.read_sql(query_6, conn)
#       7 display(result_6)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SUM(pts)WHERE=1610612747': near "SUM": syntax error

# %%
# TODO: Write your query
query_7 = "AVG(pts)""FROM = team_game_stats"



result_7 = pd.read_sql(query_7, conn)
display(result_7)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: near "AVG": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[23], line 6
#       1 # TODO: Write your query
#       2 query_7 = "AVG(pts)""FROM = team_game_stats"
# ----> 6 result_7 = pd.read_sql(query_7, conn)
#       7 display(result_7)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'AVG(pts)FROM = team_game_stats': near "AVG": syntax error

# %%
# TODO: Write your query
query_9 = "COUNT(*)""WHERE state = 'California'"

"""

result_9 = pd.read_sql(query_9, conn)
display(result_9)
# Out:
#   Cell In[24], line 4
#     """
#     ^
# _IncompleteInputError: incomplete input

# %%
# TODO: Write your query
query_10 = "Min(year_founded)"

"""

result_10 = pd.read_sql(query_10, conn)
display(result_10)
# Out:
#   Cell In[27], line 4
#     """
#     ^
# _IncompleteInputError: incomplete input

# %%
# TODO: Write your query
query_11 = "SELECT team_id""COUNT(*)"

"GROUP BY team_id"

result_11 = pd.read_sql(query_11, conn)
display(result_11.head(10))  # Show first 10 teams
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such function: team_idCOUNT
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[29], line 6
#       2 query_11 = "SELECT team_id""COUNT(*)"
#       4 "GROUP BY team_id"
# ----> 6 result_11 = pd.read_sql(query_11, conn)
#       7 display(result_11.head(10))  # Show first 10 teams
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT team_idCOUNT(*)': no such function: team_idCOUNT

# %%
# TODO: Write your query
query_12 = "GROUP BY team_id""ORDER BY avg_points DESC"

"""

result_12 = pd.read_sql(query_12, conn)
display(result_12.head(10))  # Show first 10 teams
# Out:
#   Cell In[30], line 4
#     """
#     ^
# _IncompleteInputError: incomplete input

# %%
# TODO: Write your query
query_13 = "SELECT
t.full_name as team,
t.city,
COUNT(tgs.game_id) as games_played
FROM teams t
JOIN team_game_stats tgs ON t.team_id = tgs.team_id
WHERE tgs.season = '2021-22'
GROUP BY t.team_id, t.full_name, t.city
ORDER BY games_played DESC""

"""

result_13 = pd.read_sql(query_13, conn)
display(result_13.head(10))
# Out:
#   Cell In[31], line 2
#     query_13 = "SELECT
#                ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# TODO: Write your query
query_18 = "COUNT(*)""GROUP BY team_id"

"""

result_18 = pd.read_sql(query_18, conn)
display(result_18.head(10))
# Out:
#   Cell In[32], line 4
#     """
#     ^
# _IncompleteInputError: incomplete input
